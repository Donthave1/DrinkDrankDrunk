# %%
import pandas as pd
import numpy as np
import pymongo

# %%
conn = 'mongodb://test:password1@ds123444.mlab.com:23444/heroku_3t530jfl'
client = pymongo.MongoClient(conn)

# %%
db=client.heroku_3t530jfl

# %%
collection = db.wine_db

# %%
wine_df = pd.read_csv("Final_Clean_Data.csv")
wine_df.head()
# Out:
#    Unnamed: 0  index Wine Type    Country  Final Price  Grape Variety  \
# 0           0     32   Dessert  Australia        19.99           Port
# 1           1     39   Dessert   Portugal        29.99           Port
# 2           2     42   Dessert  Australia        18.99  Other Dessert
# 3           3     45   Dessert   Portugal        51.99           Port
# 4           4     49   Dessert   Portugal        17.99           Port
#
#    Rating Score                            Wine Name alcohol_percent  \
# 0            92  Yalumba Antique Reserve Tawny Port              19%
# 1            93    Taylor Fladgate 10 Year Old Tawny             20%
# 2            94       Yalumba Museum Reserve Muscat              18%
# 3            95    Taylor Fladgate 20 Year Old Tawny          19-20%
# 4            91          Quinta do Noval Noval Black          19-20%
#
#                  food_pairing  Unnamed: 10  alcohol_percent_lower  \
# ...

# %%
wine_df.dtypes
# Out:
# Unnamed: 0                 int64
# index                      int64
# Wine Type                 object
# Country                   object
# Final Price              float64
# Grape Variety             object
# Rating Score               int64
# Wine Name                 object
# alcohol_percent           object
# food_pairing              object
# Unnamed: 10              float64
# alcohol_percent_lower      int64
# alcohol_percent_upper      int64
# dtype: object

# %%
wine_type = wine_df["Wine Type"]
price = wine_df["Final Price"]
grape_variety = wine_df["Grape Variety"]
score = wine_df["Rating Score"]
brand_name = wine_df["Wine Name"]
food_pairing = wine_df["food_pairing"]
lower_alcohol = wine_df["alcohol_percent_lower"]
upper_alcohol = wine_df["alcohol_percent_upper"]

# %%
x=0

while x < len(wine_df["Wine Type"]):
    post = {
        "brand_name": brand_name[x],
        "wine_type": wine_type[x],
        "grape_type": grape_variety[x],
        "price": float(price[x]),
        "review": int(score[x]),
        "food_pairing": food_pairing[x],
        "lower_alcohol": int(lower_alcohol[x]),
        "upper_alcohol": int(upper_alcohol[x])
    }
    print(post)
    collection.insert_one(post)
    x+=1
# Out:
# {'brand_name': 'Yalumba Antique Reserve Tawny Port ', 'wine_type': 'Dessert', 'grape_type': 'Port', 'price': 19.99, 'review': 92, 'food_pairing': 'Chocolate and Caramel', 'lower_alcohol': 19, 'upper_alcohol': 19}
# {'brand_name': 'Taylor Fladgate 10 Year Old Tawny', 'wine_type': 'Dessert', 'grape_type': 'Port', 'price': 29.99, 'review': 93, 'food_pairing': 'Chocolate and Caramel', 'lower_alcohol': 20, 'upper_alcohol': 20}
# {'brand_name': 'Yalumba Museum Reserve Muscat ', 'wine_type': 'Dessert', 'grape_type': 'Other Dessert', 'price': 18.99, 'review': 94, 'food_pairing': 'Chilis and Hot Spicy Foods', 'lower_alcohol': 18, 'upper_alcohol': 18}
# {'brand_name': 'Taylor Fladgate 20 Year Old Tawny', 'wine_type': 'Dessert', 'grape_type': 'Port', 'price': 51.99, 'review': 95, 'food_pairing': 'Chocolate and Caramel', 'lower_alcohol': 19, 'upper_alcohol': 20}
# ...
